# %%
import pandas as pd
import fastf1

session = fastf1.get_session(2018, 'Spain', 'FP3')

session.load()

session.results
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Practice 3 [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# ...

# %%
laps = session.laps.pick_drivers('ALO')
fastest = laps.pick_fastest()

tel = fastest.get_car_data().add_distance()
tel.head()

fastest
# Out:
# Time                      0 days 00:50:06.811000
# Driver                                       ALO
# DriverNumber                                  14
# LapTime                   0 days 00:01:18.847000
# LapNumber                                   13.0
# Stint                                        3.0
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:22.153000
# Sector2Time               0 days 00:00:29.438000
# Sector3Time               0 days 00:00:27.256000
# Sector1SessionTime        0 days 00:49:10.117000
# Sector2SessionTime        0 days 00:49:39.555000
# Sector3SessionTime        0 days 00:50:06.811000
# SpeedI1                                    286.0
# SpeedI2                                    302.0
# SpeedFL                                    282.0
# SpeedST                                    312.0
# IsPersonalBest                              True
# ...

# %%
driver_to_pick = 'ALO'

laps = session.laps.pick_drivers(driver_to_pick)

df_laps_driver = laps[['Driver', 'LapTime', 'LapNumber']].reset_index().drop('index', axis=1)

def td_to_str(td):
    if pd.isna(td):
        return None
    total_seconds = int(td.total_seconds())        
    minutes = total_seconds // 60
    seconds = total_seconds % 60
    ms = td.microseconds // 1000                      
    return f"{minutes}:{seconds:02d}:{ms:03d}"

df_laps_driver['LapTime'] = df_laps_driver['LapTime'].apply(td_to_str)

df_laps_driver.to_csv(f'../src/data/lapTimeDataTest_{driver_to_pick}.csv', index=False)
